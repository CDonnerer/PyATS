# %% [markdown]
# # Powder XRD: CsCl

# %%
from core.lattice import *
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Create structure

# %%
CsCl = Lattice([4.119],'P m -3 m')

# %%
CsCl.add_atom('Cs',[0.5,0.5,0.5])
CsCl.add_atom('Cl',[0.0,0.0,0.0])

# %% [markdown]
# ## XRD

# %%
# set up diffraction experiment
CsCl.diffraction(6000)

# %%
# plot powder pattern
CsCl.diffract.powder()

# %%
refs = CsCl.diffract.generate_reflections(n=20)
refs.head(10)
# Out:
#           tth  h  k  l   m         int
# 0   29.054209  0  0  1   6   38.071393
# 1   41.554832  1  0  1  12  100.000000
# 2   51.502399  1  1  1   8   11.840276
# 3   60.221883  0  0  2   6   16.920184
# 4   68.234844  1  0  2  24   16.421064
# 5   75.820309  1  1  2  24   35.380563
# 6   90.384745  2  0  2  12   12.282822
# 7   97.617226  0  0  3   6    2.049752
# 8   97.617226  2  1  2  24    8.199008
# 9  104.974775  1  0  3  24   21.794473

# %% [markdown]
# ## Interactive version: plotly

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# prepare label
hkl_label = np.array([refs.h,refs.k,refs.l]).T
n = len(refs.h)

text=['('+'{:d}'.format(refs.h[k])
         +'{:d}'.format(refs.k[k])
         +'{:d}'.format(refs.l[k])+')'
         +'<br> tth='+'{:.2f}'.format(refs.tth[k])
         +'<br> int='+'{:.2f}'.format(refs.int[k])
                   for k in range(n)]

# %%
trace1 = go.Scatter(
    x = refs.tth,
    y = 0*refs.int-10,
    mode = 'markers',
    marker = dict(
        size = 5,
        color = 'rgba(255, 182, 193, 1.0)'),
    hoverinfo='text',
    showlegend = False,
    text=text)

# %%
def lorz(x,a,c,w):
    L = a*w**2 / ( (x-c)**2 + w**2 )
    return L

x=np.arange(0,180,.05)
y=np.zeros_like(x)

for t,s in zip(refs.tth, refs.int):
    y += lorz(x,s,t,.1)

trace2 = go.Scatter(
    x = x,
    y = y+5,
    hoverinfo='none',
    showlegend = False,
    line = dict(
            width = 1,
            color = 'rgba(0, 0, 200, 1.0)')
)

# %%
iplot([trace1, trace2])
# Out:
# <div id="33237db7-5784-4eb9-9d51-5248aa517dc2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("33237db7-5784-4eb9-9d51-5248aa517dc2", [{"showlegend": false, "text": ["(001)<br> tth=29.05<br> int=38.07", "(101)<br> tth=41.55<br> int=100.00", "(111)<br> tth=51.50<br> int=11.84", "(002)<br> tth=60.22<br> int=16.92", "(102)<br> tth=68.23<br> int=16.42", "(112)<br> tth=75.82<br> int=35.38", "(202)<br> tth=90.38<br> int=12.28", "(003)<br> tth=97.62<br> int=2.05", "(212)<br> tth=97.62<br> int=8.20", "(103)<br> tth=104.97<br> int=21.79", "(113)<br> tth=112.60<br> int=8.17", "(222)<br> tth=120.67<br> int=8.03", "(203)<br> tth=129.49<br> int=10.07", "(213)<br> tth=139.62<br> int=68.38"], "marker": {"color": "rgba(255, 182, 193, 1.0)", "size": 5}, "mode": "markers", "hoverinfo": "text", "y": [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0,