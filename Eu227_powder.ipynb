# %%
from core.lattice import *
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# create lattice
Eu227 = Lattice([10.3],'F d -3 m')

# %%
# atomic positions
Eu227.add_atom('Eu',[0.5,0.5,0.5])
Eu227.add_atom('Ir',[0.0,0.0,0.0])
Eu227.add_atom('O' ,[0.375,0.375,0.375])
Eu227.add_atom('O' ,[0.332,0.125,0.125])

# %%
# set up diffraction experiment
Eu227.diffraction(6000)

# %%
# plot powder pattern
Eu227.diffract.powder()

# %%
refs = Eu227.diffract.generate_reflections(n=20)
refs.head(10)
# Out:
#            tth  h  k  l   m         int
# 0    20.011088  1  1  1   8    2.160554
# 1    32.964930  2  0  2  12    0.030101
# 2    38.864672  1  1  3  24    2.012745
# 3    40.667362  2  2  2   8   90.672326
# 4    47.311858  0  0  4   6   33.251436
# 5    51.856440  3  1  3  24    0.000179
# 6    58.868009  2  2  4  24    0.110219
# 7    62.829640  1  1  5  24    0.063226
# 8    62.829640  3  3  3   8    0.548849
# 9    69.144329  4  0  4  12   38.595002
# 10   72.803989  3  1  5  48    0.414689
# 11   78.754172  2  0  6  24    0.033804
# 12   82.261889  3  3  5  24    0.327380
# 13   83.424014  2  2  6  24   40.586041
# 14   88.050268  4  4  4   8   10.588158
# 15   91.509970  1  1  7  48    0.110972
# 16   97.294740  4  2  6  48    0.002161
# 17  100.798006  3  1  7  56    0.919889
# 18  100.798006  7  3  1  16    0.262826
# 19  106.736448  0  0  8   6    8.951448
# 20  110.386020  3  3  7  24    0.000252
# 21  116.677362  6  0  6  28    0.105445
# 22  116.677362  2  2  8   8    0.036927
# 23  120.619849  5  1  7  56    0.407127
# 24  121.969253  6  2  6  24   35.430877
# 25  127.586770  4  0  8  24   35.216210
# 26  132.092986  1  1  9  56    0.653518
# 27  132.092986  9  1  1  16    0.186719
# 28  140.440033  6  4  6  24    0.054228
# 29  146.235811  3  1  9  48    0.644602
# 30  158.741588  4  4  8  24  100.000000
# 31  172.898280  3  3  9  72    1.406412
